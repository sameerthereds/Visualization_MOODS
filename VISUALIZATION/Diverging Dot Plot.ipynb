# %%
import pandas as pd 
import matplotlib.pyplot as plt


stressors_dict={"Stressors":["Morning at home on weekend", "Afternoon at park with family on weekend","Friday evening with friends",
                            "Watching news at home","Watching soccer on the weekend Morning", "Cooking at home", "Mowing the garden on weekend",
                            "Sprint planning on Fridays Afternoon", "Monday 10 AM meeting with manager","Soccer on SUnday Afternoon",
                            "Driving on Friday Evening","Paying bills at end of the month", "Hospital visit every Sunday",
                             "Finding parking space at office", "Pulled over by Police","Getting late for work"],
                 "Count":[5,10,35,7,8,19,30,40,6,10,35,7,8,19,30,40],
                "Stressed":[0.1,0.2,0.3,0.25,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.85,0.9,0.95,1.0]}
print(len(stressors_dict["Stressors"]))

# stressors_dict={"Stressors":["Transportation","Work/School","Finance","Friends/Family","Health","Personal",
#                             "Social Media","Safety","Transportation","Work/School","Finance","Friends/Family","Health","Personal",
#                             "Social Media","Safety"],
#                 "Count":[5,10,35,7,8,19,30,40,6,10,35,7,8,19,30,40],
#                 "Stressed":[0.1,0.2,0.3,0.25,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.85,0.9,0.95,1.0]}
# df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mtcars.csv")
df=pd.DataFrame.from_dict(stressors_dict)
x = df.loc[:, ['Count']]
# df['mpg_z'] = (x - x.mean())/x.std()
df['colors'] = ['green' if x < 0.5 else 'red' for x in df['Stressed']]
df.sort_values('Stressed', inplace=True)
df.reset_index(inplace=True)

# Draw plot
# ax=plt.figure(figsize=(14,16), dpi= 80)
fig, ax = plt.subplots(figsize=(14,16))
plt.scatter(df.Stressed, df.index, s=2500, alpha=.6, color=df.colors)
for x, y, tex in zip(df.Stressed, df.index, df.Stressed):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='center', 
                 verticalalignment='center', fontdict={'color':'white'})

# Decorations
# Lighten borders
plt.gca().spines["top"].set_alpha(.3)
plt.gca().spines["bottom"].set_alpha(.3)
plt.gca().spines["right"].set_alpha(.3)
plt.gca().spines["left"].set_alpha(.3)

a=df.index[df['Stressed'] == 0.5].tolist()

plt.yticks(df.index, df.Stressors,fontsize=15,color="g")
# ax.get_yticklabels()[5:].set_color("red")

for i in range(a[0],len(df)):
    
    ax.get_yticklabels()[i].set_color("red")
plt.title('Context of Stressors/Non-Stressors', fontdict={'size':20})
plt.xlabel('Severity of Stress', fontdict={'size':15})
plt.grid(linestyle='--', alpha=0.5)
plt.xlim(-0.1, 1.1)

plt.axhline(y=a[0], xmin=0.4, xmax=0.6, color='b',linewidth=5.0,linestyle="--")
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch = mpatches.Patch(color='red',capstyle='round' ,label='Stressed')
green_patch = mpatches.Patch(color='green', label='Non-Stressed')
plt.legend(handles=[red_patch,green_patch],loc="lower right",prop={"size":15})
#plt.legend(["Stressed","Not Stressed"],[plt.cm.Reds, plt.cm.Greens],loc="center",prop={'size': 16})

plt.savefig("Context_bubble.png")
# Out:
# 16

# %%
import pandas as pd 
import matplotlib.pyplot as plt
days_of_week=['Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday', 'Saturday','Sunday']
a=days_of_week
time_of_the_day=['Morning','Afternoon','Evening']
b=time_of_the_day
type_of_week=['Weekdays','Weekend']
c=type_of_week
location=["Home","Work","On the road","Others"]
d=location
prep_words=["at","on","in","the"]
e=prep_words
stressors_dict={"Stressors":["Morning at home on weekend", "Afternoon at home on weekend","Friday evening at home",
                            "Evening at home on weekdays","home on the weekend Morning", "work on weekend afternoon", "driving on weekend evening",
                            "At Work on Fridays Afternoon", "Monday morning meeting at work","At home on  Sunday Afternoon",
                            "Driving on Friday Evening","Wednesday afternoon at work", "At Evening on weekend",
                             "Thursday evening at work", "Evening on the road on Friday","Monday morning on the road"],                 
                "Stressed":[0.1,0.2,0.3,0.25,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.85,0.9,0.95,1.0]}

# stressors_dict={"Stressors":["Transportation","Work/School","Finance","Friends/Family","Health","Personal",
#                             "Social Media","Safety","Transportation","Work/School","Finance","Friends/Family","Health","Personal",
#                             "Social Media","Safety"],"Count":[5,10,35,7,8,19,30,40,6,10,35,7,8,19,30,40],"Stressed":[0.1,0.2,0.3,0.25,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.85,0.9,0.95,1.0]}
# df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mtcars.csv")
df=pd.DataFrame.from_dict(stressors_dict)
# x = df.loc[:, ['Count']]
# print(x)
# df['mpg_z'] = (x - x.mean())/x.std()
df['colors'] = ['green' if x < 0.5 else 'red' for x in df['Stressed']]
df.sort_values('Stressed', inplace=True)
df.reset_index(inplace=True)

# Draw plot
fig, ax = plt.subplots(figsize=(14,18))
plt.hlines(y=df.index, xmin=0.5, xmax=df.Stressed,colors=df["colors"],linewidth=7.0)
for x, y, tex in zip(df.Stressed, df.index, df.Stressed):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0.5 else 'left', 
                 verticalalignment='center', fontdict={'color':'green' if x < 0.5 else 'red', 'size':14})

# Decorations
# Lighten borders
plt.gca().spines["top"].set_alpha(.3)
plt.gca().spines["bottom"].set_alpha(.3)
plt.gca().spines["right"].set_alpha(.3)
plt.gca().spines["left"].set_alpha(.3)



plt.yticks(df.index, df.Stressors)
a=df.index[df['Stressed'] == 0.5].tolist()
plt.yticks(df.index, df.Stressors,fontsize=15,color="g")
for i in range(a[0],len(df)):
    ax.get_yticklabels()[i].set_color("red")
plt.title('Context of Stressors/Non-Stressors', fontdict={'size':20})
plt.xlabel('Severity of Stress', fontdict={'size':15})
plt.grid(linestyle='--', alpha=1)
plt.xlim(-0.1, 1.1)

print(a)
plt.axvline(x=0.5,linewidth=4.0)
plt.axhline(y=a[0], xmin=0.4, xmax=0.6, color='b',linewidth=5.0,linestyle="--")
print(len(df))

import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch = mpatches.Patch(color='red', label='Stressed')
green_patch = mpatches.Patch(color='green', label='Non-Stressed')
plt.legend(handles=[red_patch,green_patch],loc="lower right",prop={"size":15})
plt.savefig("Context_bar.jpeg",bbox_inches='tight')

import matplotlib.pyplot as plt
import base64
from io import BytesIO
# fig = plt.figure()
#plot sth
tmpfile = BytesIO()
plt.savefig(tmpfile, format='png',bbox_inches='tight')
encoded = base64.b64encode(tmpfile.getvalue()).decode('utf-8')
html = 'Some html head' + '<img src=\'data:image/png;base64,{}\'>'.format(encoded) + 'Some more html'
with open('Context_bar.html','w') as f:
    f.write(html)
plt.tight_layout()
plt.show()
# Out:
# [6]
# 16

# %%
days_of_week=['Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday', 'Saturday','Sunday']
time_of_the_day=['Morning','Afternoon','Evening']
type_of_week=['Weekdays','Weekend']
location=["Home","Work","On the road","Others"]

# %%
import plotly.graph_objects as go
import colorlover as cl
fig = go.Figure()

fig.add_trace(go.Bar(
        x = df["Stressed"],
        y = df.Stressors,
        name = column,
        orientation = 'h',
    ))

fig.update_layout(
    barmode = 'stack',
    title = 'Twitter Sentiment Analysis of US Airlines'
)
fig.show()
# Out:
# <div>                            <div id="40f4badf-6f7a-489c-9d48-86acf6a57789" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40f4badf-6f7a-489c-9d48-86acf6a57789")) {                    Plotly.newPlot(                        "40f4badf-6f7a-489c-9d48-86acf6a57789",                        [{"name": "colors", "orientation": "h", "type": "bar", "x": [0.1, 0.2, 0.25, 0.3, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.85, 0.9, 0.95, 1.0], "y": ["Morning at home on weekend", "Afternoon at home on weekend", "Evening at home on weekdays", "Friday evening at home", "home on the weekend Morning", "work on weekend afternoon", "driving on weekend evening", "At Work on Fridays Afternoon", "Monday morning meeting at work", "At home on  Sunday Afternoon", "Driving on Friday Evening", "Wednesday afternoon at work", "At Evening on weekend", "Thursday evening at work", "Evening on the road on Friday", "Monday morning on the road"]}],                        {"barmode": "stack", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.88888888 ...

# %%
df
# Out:
#     index                       Stressors  Stressed colors
# 0       0      Morning at home on weekend      0.10  green
# 1       1    Afternoon at home on weekend      0.20  green
# 2       3     Evening at home on weekdays      0.25  green
# 3       2          Friday evening at home      0.30  green
# 4       4     home on the weekend Morning      0.40  green
# 5       5       work on weekend afternoon      0.45  green
# 6       6      driving on weekend evening      0.50    red
# 7       7    At Work on Fridays Afternoon      0.55    red
# 8       8  Monday morning meeting at work      0.60    red
# 9       9    At home on  Sunday Afternoon      0.65    red
# 10     10       Driving on Friday Evening      0.70    red
# 11     11     Wednesday afternoon at work      0.75    red
# 12     12           At Evening on weekend      0.85    red
# 13     13        Thursday evening at work      0.90    red
# 14     14   Evening on the road on Friday      0.95    red
# 15     15      Monday morning on the road      1.00    red
