# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
x_var = 'manufacturer'
groupby_var = 'class'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# %%
df_agg.head(10)
# Out:
#     manufacturer       class
# 0           audi     compact
# 1           audi     compact
# 2           audi     compact
# 3           audi     compact
# 4           audi     compact
# ..           ...         ...
# 97          ford  subcompact
# 98          ford  subcompact
# 99         honda  subcompact
# 108      hyundai     midsize
# 109      hyundai     midsize
#
# [65 rows x 2 columns]

# %%
group_names=['Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday', 'Saturday','Sunday']
stressors=["Transportation","Work/School","Finance","Friends/Family","Health","Personal", 'Hit/Run',
           "Social Media","Safety","Transportation","Work/School","Finance","Friends/Family","Health","Personal", 'Hit/Run',
          "Transportation","Work/School","Finance","Friends/Family",""]

# %%
# df_stressors={"Monday":["Transportation","Health"],
#               "Tuesday":["Transportation"],
#               "Wednesday":["Transportation"],
#               "Thursday":["Health"],
#               "Friday":["Finance"],
#               "Saturday":["Finance"],
#               "Sunday":["Finance"]
    
#             }
# stressors_df=pd.DataFrame.from_dict(df_stressors)
# stressors_df=stressors_df.reset_index()
# print(stressors_df)

# %%
df=pd.read_csv("Stressors_day .csv")
df=df.sort_values(by=['Day'])
print(df.head(5))
x_var = 'Day'
groupby_var = 'Stressors'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
fig, ax = plt.subplots(figsize=(16,9), dpi= 100)
#plt.figure(figsize=(16,9), dpi= 100)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = ax.hist(vals, df[x_var].unique().__len__(), stacked=False,rwidth=0.4, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f" Histogram of ${x_var}$ colored by ${groupby_var}$", fontsize=22)
# plt.xlabel(x_var)
plt.ylabel("Frequency")
plt.ylim(0, 5)
labels=['Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday', 'Saturday','Sunday']
#plt.xticks(ticks=bins, labels=['Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday', 'Saturday','Sunday'], rotation=90, horizontalalignment='right')
ax.set_xticklabels(labels, rotation=45, ha='right')
# plt.setp( ax.xaxis.get_majorticklabels(), rotation=-45, ha="right" )
plt.savefig("hist_stressors.png")
plt.show()
# Out:
#        Day Stressors
# 25  Friday    Honked
# 32  Friday   Finance
# 11  Friday  Personal
# 4   Friday    Honked
# 18  Friday    health

# %%
labels=np.unique(df[x_var]).tolist()
print(sorted(labels))
# Out:
# ['Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday']
