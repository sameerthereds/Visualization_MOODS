# %%
import pickle
from datetime import date
import pandas as pd
def read_pickled_files():   

    users_today={}
    with open('/home/jupyter/sneupane/MOODS/pickled_files/user_profile.pickle', 'rb') as handle:
        user_profile = pickle.load(handle)
    with open('/home/jupyter/sneupane/MOODS/pickled_files/users_today.pickle', 'rb') as handle:
        users_today = pickle.load(handle)
#     if len(users_today) > 0:
#         for user in users_today:
#             users_today_dict[user]=user_profile[user][5]
    return user_profile,users_today

user_profile,users_today=read_pickled_files()


# for study
week_visualizations={
 "1":["Overall_Average","Prominent_Stressor_Context"],  
 "2":["Map_View"],    
 "3":["Prominent_Stressors"],  
 "4":["Location_Prominence"],  
 "5":["Calendar_View"],# reverse 5 and 6 
"6":["Stressor_Ranking"],
 "7":["Weekly_Trend"],  
 "8":["Weekly_Prevalence"],  
 "9":["Time_of_day_Trend"],  
 "10":["Location_Trend"],
 "11":["Daily_Trend"],  
 "12":["Duration_Analysis"],  
 "13":["Stressor_Analysis"],    
 "14":["Word_Cloud"],  
}


#for pilot
# week_visualizations={
#  "1":["Overall_Average","Prominent_Stressor_Context"],  
#  "2":["Prominent_Stressors"],    
#  "3":["Location_Prominence"],  
#  "4":["Calendar_View"],  
#  "5":["Stressor_Ranking"],
# "6":["Weekly_Trend"],
#  "7":["Weekly_Prevalence"],  
#  "8":["Time_of_day_Trend"],  
#  "9":["Location_Trend"],  
#  "10":["Daily_Trend"],
#  "11":["Duration_Analysis"],  
#  "12":["Stressor_Analysis"],  
#  "13":["Stressor_Analysis"],    
#  "14":["Summary"],  
# }
user_vis_creation={}
for user in user_profile:
    temp_dict={}
    temp=""
    for week in range(1,15):
        if len(temp)>0:
            temp=temp+","+ ",".join(week_visualizations[str(week)])
        else:
            temp=temp+ ",".join(week_visualizations[str(week)])
        
#         temp_dict[week]=temp
        
        temp_split=temp.split(',')
        temp_dict[week]=temp_split
#         print(week,temp)
    user_vis_creation[user]=temp_dict
    
with open('/home/jupyter/sneupane/MOODS/pickled_files/user_vis_creation.pickle', 'wb') as handle:
            pickle.dump(user_vis_creation, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
figure_intro={}
#---------------------------------------------------------------------------#
figure_intro["Overall Average"]="Your average stress duration and number of daily stressors"
#---------------------------------------------------------------------------#
figure_intro["Map View"]="GPS locations of where you are usually stressed."
#---------------------------------------------------------------------------#
figure_intro["Prominent Stressors"]="Contribution of Daily Stressors to total stressed duration"
#---------------------------------------------------------------------------#
figure_intro["Calendar View"]="Which days and at what times are you usually stressed."
#---------------------------------------------------------------------------#
figure_intro["Time of day Trend"]="Occurence of daily stressors for different times of day across various weeks"
#---------------------------------------------------------------------------#
figure_intro["Location Trend"]="Occurence of daily stressors for various locations across various weeks"
#---------------------------------------------------------------------------#
figure_intro["Prominent Stressor Context"]="Place and time of occurrence for the most frequent stressors"
#---------------------------------------------------------------------------#
figure_intro["Daily Trend"]="Occurence of daily stressors  across days of the weeks"
#---------------------------------------------------------------------------#
figure_intro["Duration Analysis"]="Distribution of stressed minutes for top stressors "
#---------------------------------------------------------------------------#
figure_intro["Stressor Analysis"]="Comparison of stressed duration of daily stressors across weeks"
#---------------------------------------------------------------------------#
figure_intro["Weekly Trend"]="Trend of occurence of daily stressors"
#---------------------------------------------------------------------------#
figure_intro["Weekly Prevalence"]="Occurence of each stressor across all the weeks "
#---------------------------------------------------------------------------#
figure_intro["Location Prominence"]="Distribution of total stressed duration across reported locations"
#---------------------------------------------------------------------------#
figure_intro["Stressor Ranking"]="Ranking of stressors based on stress probability."
#---------------------------------------------------------------------------#
figure_intro[""]=""
#---------------------------------------------------------------------------#
figure_intro["Word Cloud"]="Word Cloud of Stressor and Location."




figure_description={}

#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Overall Average"]="""This graph shows the following items: Weekly average (all previous weeks combined) of minutes stressed per hour;   
Current week average stressed minutes; Weekly average (all previous weeks combined) number of daily stressors; Current week number of daily stressors."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Calendar View"]="""This graph shows the days and times when the system detects that you are usually 
stressed. You can hover/tap over each segment to see the expansion of the abbreviation,  corresponding stress probability and the
average stressed minutes of each hour 
detected by the MOODS app. The color bar in the right corresponds to the stress probability values."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#

figure_description["Map View"]="""This graph shows the various semantic locations in the map where you have reported being stressed. You can hover/tap over each point 
to see the corresponding stressor, day and time of the day of its occurence. If there are new locations reported for current week, you can also click/tap the legend to see 
new locations reported for current week."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#

figure_description["Prominent Stressor Context"]="""This graph shows the location and time of day for your five most frequently reported stressors. You can tap-in and tap-out on
each stressor to see the location and time of day of the occurrence for that particular stressor selected.  Tapping on a segment will return you to the main graph."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Weekly Trend"]="""This graph shows how many times you reported your daily stressors every week. 
You can toggle on/toggle off different stressors to see them on the graph."""

#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#

figure_description["Weekly Prevalence"]="""This graph shows the number of times each stressor was reported.You can hover/tap over each segment 
to see the expansion of the abbreviation, week number and number of occurences."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Location Prominence"]="""This graph shows distribution of stressed duration across reported locations . 
You can click on or tap the legend to view the percentage for a particular location."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Time of day Trend"]="""This graph shows a scatter plot for your stressors over the weeks of your study participation and the time of the day. 
To select each stressor, click/tap the corresponding legend item."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Location Trend"]="""This graph shows a scatter plot for your stressors over the weeks of your study participation and different locations.
To select each stressor, click/tap the corresponding legend item."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#

figure_description["Horizontal_Bar_Time"]="""This graph shows how often  a particular stressor occurs across different parts of a day. For example, 50% morning and 50% evening for a given stressor means that stressor was 
reported in the morning for half of all of that stressor's reports, and the other half of the time that stressor was reported in the evening. 
Hovering over / Clicking a bar will expand the abbreviations of the stressors on the left"""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Prominent Stressors"]="""This graph shows contribution of each stressor to the total stressed duration. 
You can also hover/tap over each segment to expand the abbreviations and see the percentage."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Daily Trend"]="""This graph shows how many times a stressor was reported across the different days of the week
since the beginning of the study to date. To select each stressor, click/tap the corresponding legend item."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Duration Analysis"]="""This graph shows violin plots of that depict the duration of your five most frequently reported stressors. Violin plots consist 
of box plots (seen toward the center of each violin) and it also shows the probability density of the data at different values, 
usually smoothed by a kernel density estimator. \n A boxplot is a method for graphically depicting groups of numerical data through their quartiles.
Kernel density estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable. 
A probability density function (PDF) of a  random variable, is a function whose value at any given sample (or point) in the sample space (the set of possible values  
taken by the random variable) can be interpreted as providing a relative likelihood that the value of the random variable would equal that sample."""
#---------------------------------------------------------------------------#
#---------------------------------------------------------------------------#
figure_description["Stressor Analysis"]="""This graph shows  how long duration of stressed periods were detected by the MOODS app for five top stressors across
the weeks  you have participated in the study. <span class="red">Red</span> bars show current week and gray bars 
show previous weeks. """
#---------------------------------------------------------------------------#
figure_description["Word Cloud"]="This graph shows the word cloud of your stressors and reported locations." 
#---------------------------------------------------------------------------#
figure_description["Stressor Ranking"]="This graph shows the ranking of your daily stressors based on stress probability. " 
figure_description[""]="" 



data_summary_user={}

for user in user_profile:
    data_summary={}
    #---------------------------------------------------------------------------#
    data_summary["Overall Average"]=""""""
    
    #---------------------------------------------------------------------------#
    #---------------------------------------------------------------------------#
    data_summary["Map View"]="""<ul><li><b>New Stressed locations reported in  Week week_num :</b> _a_</li> </ul>"""
    #---------------------------------------------------------------------------#
    data_summary["Prominent Stressors"]="""<ul><li><b>Stressor with longest reported stressed duration for Week week_num was:</b> _a_</li></ul>"""
    #---------------------------------------------------------------------------#
    data_summary["Location Prominence"]="""<ul><li><b>Location with longest reported stressed duration for Week week_num was:</b> _a_</li></ul>"""
    #---------------------------------------------------------------------------#
    data_summary["Calendar View"]=""""""
    #---------------------------------------------------------------------------#
    data_summary["Time of day Trend"]="""<ul><li><b>Stressors were reported the most this Week week_num in :</b> _a_</li>   
    <li><b>Stressors were reported the most in previous weeks in :</b> _b_   </li> </ul>"""
    #---------------------------------------------------------------------------#
    data_summary["Location Trend"]="""<ul><li><b>Stressors were reported the most this Week week_num was at :</b>_a_</li>   
    <li> <b>Stressors were reported the most in previous weeks was at :</b> _b_   </li> </ul>"""
    #---------------------------------------------------------------------------#
    data_summary["Prominent Stressor Context"]="""<ul> <li><b>The most frequent stressors since the study are :</b> _a_</li>
    <li><b>Stressor that was added to most frequent list after Week week_num:</b> _b_</li><ul>"""
    #---------------------------------------------------------------------------#
    data_summary["Daily Trend"]="""<ul><li>Week week_num, stressors reported the most on : _a_ </li>
    <li>In previous weeks, you reported stressors the most on : _b_ </li></ul>"""
    #---------------------------------------------------------------------------#
    data_summary["Duration Analysis"]=""
    #---------------------------------------------------------------------------#
    data_summary["Stressor Analysis"]="""""" 

    
    #---------------------------------------------------------------------------#
    data_summary["Weekly Trend"]=""""""
    #---------------------------------------------------------------------------#
    data_summary["Weekly Prevalence"]=""""""
    #---------------------------------------------------------------------------#
    data_summary["Stressor Ranking"]=""""""
    #---------------------------------------------------------------------------#
   
    data_summary["Word Cloud"]=""""""
    data_summary[""]=""""""
    #---------------------------------------------------------------------------#
    data_summary_user[user]=data_summary
    
    
import pickle

with open('/home/jupyter/sneupane/MOODS/pickled_files/figure_intro.pickle', 'wb') as handle:
    pickle.dump(figure_intro, handle, protocol=pickle.HIGHEST_PROTOCOL)

    
with open('/home/jupyter/sneupane/MOODS/pickled_files/figure_description.pickle', 'wb') as handle:
    pickle.dump(figure_description, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('/home/jupyter/sneupane/MOODS/pickled_files/data_summary_user.pickle', 'wb') as handle:
    pickle.dump(data_summary_user, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
print("**************************************************************************")
print("finished")
print("**************************************************************************")
# Out:
# **************************************************************************
# finished
# **************************************************************************

# %%
users_today
# Out:
# ['7d9937db-7133-3f39-8c50-a70fc1a53f5c',
#  '35f7fd27-e07e-3332-8908-3638b66f01f8',
#  'b3991d3b-f8d0-3c64-9fc3-ad9a0b45d277',
#  '42159f10-f41f-3585-b040-540ab2dc4b93',
#  'c4d00fcf-0020-3a92-a9ee-5ecf38d137ed',
#  '50ef4edc-3cc4-3955-a21b-07b51c7a6dd0',
#  '7a6310bd-de3e-3a1b-a3bc-4671e3e6cf63',
#  '1234aa13-c97c-3c5b-abcf-249ce49a45b5',
#  '1e77b486-c4a0-3486-ade8-4b81037bb6dd',
#  '9550fabf-4992-369d-8ec8-df59a8818d59',
#  '8f9dbda4-8e32-3cb6-8c38-4d63058b1af9',
#  'a63dd8fb-704c-3b50-b62a-b40ed3f18476',
#  'b781f782-107d-3c3b-b8a3-9082e47c4212',
#  '0cdf8895-f351-34de-b43d-890a1e7ead8f',
#  'e2018413-ca27-3537-8bf6-b45265515f27',
#  'a4ce4274-c9b4-36b6-96f2-61fbd3a41dc4',
#  'd6f4844c-9688-33a3-9dca-e43debcbb839']
