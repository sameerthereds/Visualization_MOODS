# %%
import pickle
from pathlib import Path
import os
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import pandas as pd
import sqlite3
from sqlite3 import Error
import uuid
import shutil
from pathlib import Path
from datetime import datetime

with open('/home/jupyter/sneupane/MOODS/pickled_files/stressed_df.pickle', 'rb') as handle:
    final_df_stressed = pickle.load(handle)

with open('/home/jupyter/sneupane/MOODS/pickled_files/users_today.pickle', 'rb') as handle:
    users_today = pickle.load(handle)

# users_today=["e792585a-48a2-36ae-9a50-de0605f76829","e55b847f-4557-3bba-9cfd-84f261a9c8fc",
#              "12bb64cc-c191-3277-b7e3-f3cb64e20d9d",
#              "136112f5-b332-34f7-89e9-4a0e6c5f54bd","af5f95f0-09cc-3a0a-b283-1a0ae724e43c"]
# users_today=["84e96c23-1072-31cd-ab34-015b6c9c8b74"]
with open('/home/jupyter/sneupane/MOODS/pickled_files/user_profile.pickle', 'rb') as handle:
    user_profile = pickle.load(handle)
with open('/home/jupyter/sneupane/MOODS/pickled_files/figure_intro.pickle', 'rb') as handle:
    figure_intro = pickle.load(handle)
    
with open('/home/jupyter/sneupane/MOODS/pickled_files/figure_description.pickle', 'rb') as handle:
    figure_description = pickle.load(handle)
    
with open('/home/jupyter/sneupane/MOODS/pickled_files/user_vis_creation.pickle', 'rb') as handle:
    user_vis_creation = pickle.load(handle)

with open('/home/jupyter/sneupane/MOODS/pickled_files/data_summary_user.pickle', 'rb') as handle:
    data_summary_user = pickle.load(handle)
    
with open('/home/jupyter/sneupane/MOODS/pickled_files/batch_users.pickle', 'rb') as handle:
    batch_users = pickle.load(handle) 

# if running drirectly notebook    
import sys, os, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
parentdir = os.path.dirname(parentdir)
sys.path.insert(0, parentdir)
print((parentdir))

# # if running cron
# from pathlib import Path


# p = Path(os.getcwd()).parents[0]

# parentdir = os.path.dirname(p)
# print(type(parentdir))

import import_ipynb
visualizations=[]
# from visualizations import indicator,map_visual
from visualizations import no_data,Word_Cloud,Overall_Average,Map_View,Prominent_Stressor_Context,Stressor_Ranking,Prominent_Stressors,Location_Prominence,Calendar_View,Weekly_Trend,Time_of_day_Trend,Location_Trend,Weekly_Prevalence,Daily_Trend,Duration_Analysis,Stressor_Analysis
# visualizations_functions=[Overall_Average,Map_View,]
visualizations_functions=[Overall_Average,Word_Cloud,Map_View,Prominent_Stressor_Context,Prominent_Stressors,Stressor_Ranking,Location_Prominence,Calendar_View,Weekly_Trend,Time_of_day_Trend,Location_Trend,Weekly_Prevalence,Daily_Trend,Duration_Analysis,Stressor_Analysis]
no_Data_visuals=[no_data]
def generateVisualization(vis_func,dataframe,user,week_num,data_summary_current_user):
    return vis_func.create_visualization(dataframe,user,week_num,data_summary_current_user)


def content_write(fig_name,fig,figure_description_user,data_summary):       
    data_sum=data_summary[fig_name]    
    fig_name_header = "<h2 <b>{}</b></h2>".format(fig_name)
    if len(figure_description_user[fig_name]) > 0:
        fig_des = " <h6><b>Graph Description</b></h6><p>{}</p>".format(figure_description_user[fig_name])
    else:
        fig_des = "<p>{}</p>".format(figure_description_user[fig_name])
    if len(data_sum) > 0:
        data_sum = " <h6><b>Findings this week: </b></h6><p>{}</p>".format(data_summary[fig_name])
    else:
        data_sum = "<p>{}</p>".format(data_summary[fig_name])
    
    fig = "{}".format(fig)
    top_html="""\
   <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta http-equiv="X-UA-Compatible" content="IE=edge">
        <meta name="viewport" content="width=device-width, initial-scale=1">
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
        <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
        <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
        <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
        <style>
         html,body{{
                height:100vh;

            }}
        a {{
        text-decoration: underline;
            }}
p{{margin:0;}}
h6{{margin:0;}}
            .flex-fill {{
                flex:1;
            }}
            
         
.red {{ color: #FF0000; font-weight:bold; }}
.green{{color:#006400;font-weight:bold; }}
.bold {{ font-weight:bold;  }}
.shade{{color:grey;

}}



.header {{
  overflow: hidden;
  background-color: #1E88E5;
  padding: 20px 10px;
}}

.header a {{
  float: left;
  color: black;
  text-align: center;
  padding: 12px;
  text-decoration: none;
  font-size: 18px; 
  line-height: 25px;
  border-radius: 4px;
 
}}

.header a.logo {{
  font-size: 25px;
  font-weight: bold;
}}

.header a:hover {{
  background-color: #1E88E5;
  color: black;
}}

.header a.active {{
  text-decoration: underline;
  color: white;
}}

.header-right {{
  float: right;
}}


@media screen and (max-width: 500px) {{
  .header a {{
    float: none;
    display: block;
    text-align: left;
  }}
  
  .header-right {{
    float: none;
  }}
 
}}

        </style>    
        </head>
        <body>
        <br>
         
            <div class="header" id={2}>
              <a href="#default" class="logo">{0}</a>
              <div class="header-right">
                <a class="active" href="#Home_Page">Back to Top</a>
            </div>
            </div>
            <br>
            <div id="Fig_desc" class="container" style="border:3px solid black" ;"border-style: solid";  "border-width: medium"; > 
               
                {3}
                
                {4}

            </div> 
<br>
<br>
            <div class="container_fluid">
            {1}
            </div>
        </body>
    </html>
    """.format(fig_name_header,fig,fig_name.replace(" ","_"),fig_des,data_sum)
    
    return top_html


def context_html(fig_list,week_num_str):

#     fig_lists = ["\n    <li class= list-group-item  style= height: 40px; padding: 10px 15px><a href = #{}><b>{}</b></a> :  &emsp;<small><i>{}</i></small></li>".format(s,s,figure_intro[s]) for s in fig_list]
    fig_lists = ["\n    <li><a href = #{}><b>{}</b></a> : <i> &emsp;{}</i></li>".format(s.replace(" ","_"),s,figure_intro[s]) for s in fig_list]
    fig_lists = "".join(fig_lists)
   
    context_html="""\
   
    <html lang="en">
     <head>
          <title>Weekly Visualization</title>
          <meta charset="utf-8">
          <meta name="viewport" content="width=device-width, initial-scale=1">
          <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
          <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
          <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
          <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
            <link rel="stylesheet" href="https://www.w3schools.com/w3css/4/w3.css">
        <style>
            .jumbotron {{
                     background-image: linear-gradient(315deg, #20bf55 0%, #01baef 74%) fixed center no-repeat;
                     background-size: cover;
                }}
        .info {{
  background-color: #e7f3fe;
  border-left: 6px solid #2196F3;
}}
        </style>
        </head>
        <body>
        <link href="cache/223ks2j3jdmam4.css" data-matomo-href="uncached.css">
<script type="text/javascript">
  var _paq = window._paq = window._paq || [];
  _paq.push(['HeatmapSessionRecording::disable']);
  /* tracker methods like "setCustomDimension" should be called before "trackPageView" */
  _paq.push(['trackPageView']);
  _paq.push(['enableHeartBeatTimer']);
  _paq.push(['enableLinkTracking']);

  (function() {{
    var u="https://odin.md2k.org/matomo/";
    _paq.push(['setTrackerUrl', u+'matomo.php']);
    _paq.push(['setSiteId', '1']);
    var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
    g.type='text/javascript'; g.async=true; g.src=u+'matomo.js'; s.parentNode.insertBefore(g,s);
  }})();

</script>
        <div class="jumbotron text-center"  style="background-image: linear-gradient(315deg, #20bf55 0%, #01baef 74%)" "border-bottom-left-radius: 50% 20%" "border-bottom-right-radius: 50% 20%">
          <img src="https://drive.google.com/uc?export=view&id=13PpeE17mJPUi9WCC_gjAs_Wa3vi_qFtE" alt="MOODS Study" class="rounded float-left"  width="104" height="70" >
          <h1>Your Personalized MOODS visualizations for Week {0}</h1>
        </div>
        <div class="w3-container" id="Home_Page" >
          <h2>The list of visualizations for this week:</h2>
           <p> <i>Scroll down to view this week’s visualizations, or click/tap on a category to jump to that visualization. </i> <br>
           <i>Colors used in all of the visualizations are color blind friendly !!</i></p>
           
           <ul class="w3-ul w3-hoverable" style="margin:30">
               {1}
           </ul>
       </div>

 </div>
    </body>
    </html>""".format(week_num_str,fig_lists)
    return context_html

def word_cloud(fig_name,fig_stressor,fig_location,figure_description_user):

    fig_name_header = "<h2> <b>{}</b></h2>".format(fig_name)
    if len(figure_description_user[fig_name]) > 0:
        fig_des = " <h6><b>Graph Description</b></h6><p>{}</p>".format(figure_description_user[fig_name])
    else:
        fig_des = "<p>{}</p>".format(figure_description_user[fig_name])
    
    fig_stressor = "{}".format(fig_stressor)
    fig_location = "{}".format(fig_location)
    top_html="""\
  
<html>
<head>
<style>
* {{ box-sizing: border-box;}}

html {{
  font-size: 100%;
}}

body {{
  padding: 1rem;
  font-family: Verdana, Geneva, sans-serif;
}}

h1 {{
  font-size: 3.5rem;
  font-weight: bold;
  line-height: 1.5;  
  text-align: center;
  
}}
h1 span {{ 
   background-color:grey;
}}
h4 {{
  font-size: 2.5rem;
  font-weight: bold;
  line-height: 1.5;  
  text-align: center;
   background-color: #BDB76B;
}}


p {{
  margin: .5rem 0;
  font-size: 1.25rem;
  line-height: 1.5;
}}

/* First the Grid */
.gallery-grid {{
  
  display: grid;
  grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
  grid-template-rows: repeat(2,fr);
  grid-gap: 1.5rem;
  grid-auto-flow: dense;
  
   padding: 10px;
  margin: 0;
  padding: 0;

}}

/* The Picture Frame */
.gallery-frame {{
position: relative;
  padding: .5rem;
  font-size: 1.2rem;
  text-align: center;
 
  color:Black;
}}

/* The Images */
.gallery-img {{
  max-width: 100%;

  border: 5px solid #555;
  object-fit: cover;
  transition: opacity 0.25s ease-in-out;
}}
.small {{
 
  grid-column: auto / span ;
  grid-row: auto / span ;
  
}}
.large {{
 
  grid-column: auto / span 3;
  grid-row: auto / span 2;
  
}}
.medium {{
 
  grid-column: auto / span 2;
  grid-row: auto / span 2;
  
}}
.gallery-img:hover {{
  opacity: .7;
}}
 
</style>
</head>
<body>
 <br>
            <div class="header" id={1}>
              <a href="#default" class="logo">{0}</a>
              <div class="header-right">
                <a class="active" href="#Home_Page">Back to Top</a>
            </div>
            </div>
            <br>
             <div id="Fig_desc" class="container" style="border:3px solid black" ;"border-style: solid";  "border-width: medium"; > 
               
                {2}
                </div>
    <!-- Photo Grid -->
    <div class="gallery-grid "> 
      <div class="gallery-frame large ">
      <h4>Stressor Word Cloud</h4>


      <img class="gallery-img" src="{3}" >

      <h4>Location Word Cloud</h4>

      <img class="gallery-img" src="{4}" >


      </div>

    </div>

</body>
</html>
    """.format(fig_name_header,fig_name,fig_des,fig_stressor,fig_location )
    
    return top_html


def create_visualization(user,batch,dataframe_for_visualization,flag,adjust):
#     p = Path(os.getcwd())

    path = "/home/jupyter/sneupane/MOODS/"
   
    config = dict({
        'responsive': True,
        'fillFrame':False,
        'staticPlot': False,
        'autosizable':True,
        'displayModeBar': False,
        'editable': False,
        "scrollZoom":False,
    })


    with open('/home/jupyter/sneupane/MOODS/deployment/matomo_script.txt', 'r') as f:
        matomo = f.read()
        
    
        
    week_num=0
   
    
    print(user)
    figure_description_user={}
    data_summary_user_copy={}

    # if creating on Friday , use this

    week_num=user_profile[user][5]
#     week_num=14
    print(week_num)
    if week_num > 1:
        week_num=week_num-adjust

    # if creating after Friday, use this 

#         week_num=user_profile[user][5]-1
#         week_num=1
    figure_description_user=figure_description.copy()
    data_summary_user_copy=data_summary_user.copy()
    data_summary_current_user=data_summary_user_copy[user]

    modified_description={}


    # checks output directory is present ..If not creates output directory
    if  not os.path.exists(Path(path+"/output")):
        os.makedirs(path+"/output")   

    temp_path=path+"/output/"+user
    temp_path=Path(temp_path)
    # checks user directory is present ..If not creates output directory
    if not os.path.exists(temp_path):
        os.makedirs(path+"/output/"+user)   

    html_list={}

    # store the created visualization in the list
    data_summary_current_user_vis=""
    temp_dict={}
    visualizations_list=[]
    if week_num < 15:
        visualizations_list=user_vis_creation[user][week_num]
    else:
        visualizations_list=user_vis_creation[user][14]
    if week_num == 1:
        visualizations_list = visualizations_list
    else:
        visualizations_list = visualizations_list[-1:] + visualizations_list[:-1]

    visualizations_this_week=[]
    for vis in visualizations_list:
        for func in visualizations_functions:
            if vis == func.__name__.split(".")[1]:
                visualizations_this_week.append(func)
    visualizations=visualizations_this_week
#     print(visualizations_this_week)
#     visualizations=visualizations_functions
    figure_name,vis,data_summary_current_user_vis="","",""
    for visualization in visualizations:

#         print(generateVisualization(visualization,dataframe_for_visualization,i,week_num))
        figure_name,vis,data_summary_current_user_vis=generateVisualization(visualization,dataframe_for_visualization,user,week_num,data_summary_current_user)
        if len(figure_name)>0 and figure_name !="Word_Cloud":

            vis.update_xaxes(fixedrange=True)
            vis.update_yaxes(fixedrange=True)

            vis.update_layout(legend_title_side="top",legend=dict(title_font_family="Times New Roman",title_font_size=12,
            font=dict(
            family="Courier",
            size=10,
            color="black"
            ),
        bgcolor="LightSteelBlue",
        bordercolor="Black",
        borderwidth=2,))
        temp_dict[figure_name]=data_summary_current_user_vis
        if figure_name=="Word_Cloud":
            figure_name="Word Cloud"
    #             print((data_summary_current_user_vis))
        if len(figure_name) == 0:
            print("Visualization : "+ str(visualization.__name__)+" could not be created for this user : " + str(user) )
            vis=generateVisualization(no_Data_visuals[0],"","","","")
            html_list[visualization.__name__.split(".")[1].replace("_"," ")]=vis
            temp_dict[visualization.__name__.split(".")[1].replace("_"," ")]=data_summary_current_user_vis
        else:
    #             print("Visualization : "+ str(visualization.__name__)+" created for this user : " + str(i) )

            html_list[figure_name]=vis
    modified_description[user]=temp_dict


    # write the created visualizations to a html file
    vis_lists=';'.join(html_list.keys())
    random_uuid=str(uuid.uuid1())
    matomo_write_flag=False
    content_write_flag= False

    try:
        with open(random_uuid+'.html', 'a') as f:
            for fig in html_list:   

                    if matomo_write_flag == False or content_write_flag == False :
#                             f.write(matomo)
#                                 print(test)
#                                 f.write(test)

                            f.write(context_html(html_list,str(week_num)))

                            matomo_write_flag=True
                            content_write_flag=True

                    if fig=="Map View":
                        config["scrollZoom"]=True

                        f.write(content_write(fig,html_list[fig].to_html(full_html=False,config=config,include_plotlyjs='cdn'),figure_description_user,modified_description[user]))
                    elif fig=="Word Cloud":
                        stressor_wc="https://odin.md2k.org/moods/"+user+"/vis/week"+str(week_num)+"/"+"word_cloud/"+user+"_"+"stressor"+"_wordcloud.jpg"
                        location_wc="https://odin.md2k.org/moods/"+user+"/vis/week"+str(week_num)+"/"+"word_cloud/"+user+"_"+"location"+"_wordcloud.jpg"

                        f.write(word_cloud(fig,stressor_wc,location_wc,figure_description_user))
                    else:
                        config["scrollZoom"]=False

#                             print((data_summary_current_user_vis))
                        f.write(content_write(fig,html_list[fig].to_html(full_html=False,config=config,include_plotlyjs='cdn'),figure_description_user,modified_description[user]))

#                     f.write(html_list[fig].to_html(full_html=True,config=config))

        if os.stat(random_uuid+'.html').st_size ==0:            
            os.remove(random_uuid+'.html')
        else:
            
#                 print(datetime.datetime.now())
            # store the created visualization path in database

            conn=sqlite3.connect("/home/jupyter/sneupane/MOODS/database/moods_visualization.db")               
            c=conn.cursor() 

            c.execute("INSERT INTO users_visualization_links VALUES (?,?,?,?,?,?,?,?,?)",(user,user_profile[user][0],user_profile[user][1],week_num,vis_lists, user+"/vis/"+"/week"+str(week_num)+"/"+random_uuid+".html",datetime.now(),flag,"vis"))
            conn.commit()
            conn.close()
            temp_fig=path+"/output/"+user+"/vis"+"/week"+str(week_num)+"/"
            today_date=datetime.today().strftime('%Y-%m-%d')
            auto_output=path+"/output_automation/"+today_date+"/"+str(batch)+"/"
            # store the visualization in the corresponding user and week directory
            if not os.path.exists(temp_fig):
                os.makedirs(temp_fig)
            if os.path.exists(auto_output):
                for f in os.listdir(auto_output):
                    if user in f:
                        os.remove(os.path.join(auto_output, f))
            if not os.path.exists(auto_output):
                os.makedirs(auto_output)

            shutil.copy(random_uuid+".html", auto_output+user+"_week_"+str(week_num)+".html")
            shutil.move(random_uuid+".html", temp_fig+random_uuid+".html")
    except Exception as e:
        os.remove(random_uuid+'.html')
        print("Something is wrong")
        print(e)
# Out:
# /home/jupyter/sneupane/MOODS
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/no_data.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Word_Cloud.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Overall_Average.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Map_View.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Prominent_Stressor_Context.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Stressor_Ranking.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Prominent_Stressors.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Location_Prominence.ipynb
# importing Jupyter notebook from /home/jupyter/sneupane/MOODS/visualizations/Calendar_View.ipynb
# ...

# %%
# for user in users_today:
for batch in batch_users:
    user_batch=batch_users[batch]
    for user in user_batch:
        if user in users_today:
#         if user =="1553c614-8d53-34f8-86d8-2379ab75f0c4":
        
#             print("**************************************************************************")
            try: 
                create_visualization(user,batch,final_df_stressed,flag=1,adjust=0)
                print("Visualizations created for user: " + user + " of batch : " + str(batch))
                print("**************************************************************************")
            except Exception as e:
                print("Error occured while creating vis for :" + user_name)
                print(e)
#         print("**************************************************************************")
#     if user == "":
#         create_visualization(user,final_df_selected,flag=0,adjust=0)
# Out:
# 1553c614-8d53-34f8-86d8-2379ab75f0c4
# 12
# 29
# I
# 117
# I3
# I4
# I
# I
# 342 117
# I2
# I3
# Visualizations created for user: 1553c614-8d53-34f8-86d8-2379ab75f0c4 of batch : 18
# **************************************************************************

# %%
print("**************************************************************************")
print("finished")
print("**************************************************************************")
# Out:
# **************************************************************************
# finished
# **************************************************************************

# %%
user_profile["bfb5ea2e-96c7-3c57-b1f8-fff8c24d53f5"]
# users_today
# Out:
# [b'gAAAAABk-yJAznCV3jrDteMHBSErh2VLMza_7ijL45baCN_mmqX3yEKWD0MQAdsxFUz2AKh8dedGMSpBByW8dWtq5fj60gd2Qw==',
#  b'gAAAAABk-yJAH2RkTWjgbTJL_1Ybs3oRlgMci5ZUS6RCFWG9UJ-Y6oiPMb-HWW0EquiQMHOqD7TCoU9VsCLubU81CaWdbgNUrqF0BsCx0K32tM8UO7N0HyQ=',
#  datetime.date(2022, 4, 4),
#  datetime.date(2022, 4, 15),
#  523,
#  74]

# %%
users_today
# Out:
# ['9946618c-8ca1-3740-a6b6-15cbf89b69c3',
#  '39cf9343-b715-33bb-b7b5-6a610d826dfa',
#  '1553c614-8d53-34f8-86d8-2379ab75f0c4',
#  '5bb8535b-0c3d-3370-b026-e29abb38e697',
#  '336482c0-71cf-39c8-96bb-8aeb7ffa4d3f',
#  'c4ef872f-a0db-3a4b-beae-75b7ec7f4c6b',
#  'b9b13911-dda5-38de-bb0d-becd0c9a4c7d']

# %%
with open('/home/jupyter/sneupane/MOODS/pickled_files/stressor_abbr.pickle', 'rb') as handle:
            stressor_lemma = pickle.load(handle)

# %%
stressor_lemma["e33da7f5-9dfd-3233-b09a-e5ba7a0f6dfb"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-9f907c94d3f2> in <module>
# ----> 1 stressor_lemma["e33da7f5-9dfd-3233-b09a-e5ba7a0f6dfb"]
#
# KeyError: 'e33da7f5-9dfd-3233-b09a-e5ba7a0f6dfb'

# %%
user_df=final_df_stressed.loc[final_df_stressed["user"]=="e33da7f5-9dfd-3233-b09a-e5ba7a0f6dfb"]
# user_df=user_df.loc[user_df["Location"]!=""]

# %%
import plotly.express as px
fig=px.sunburst(user_df, path=[ 'Stressor', 'Location','start_time_of_day'], values='counter',color='Stressor',
#                          color_discrete_map=color_map,
                        hover_name="Stressor",hover_data=["Location", "start_time_of_day"])
fig.show()

# %%
user_df[["Stressor","Location"]]
